# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = False

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("VRAM:", torch.cuda.get_device_properties(0).total_memory / 1024**3)
# Out:
# PyTorch: 2.14.0+cu130
# CUDA: True
# GPU: NVIDIA GeForce RTX 4050 Laptop GPU
# VRAM: 5.63555908203125

# %%
# !nvidia-smi
# Out:
# Mon Sep 14 20:19:36 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.173.02             Driver Version: 580.173.02     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...    Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P8              2W /   60W |    4581MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3533      G   /usr/lib/xorg/Xorg                        4MiB |
# |    0   N/A  N/A           93608      C   ...rojects/SAM3/.venv/bin/python       4558MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sam3
import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
# Out:
# /home/girish/Documents/Projects/SAM3/sam3/sam3/model_builder.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /home/girish/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/jit/_script.py:1491: FutureWarning: `torch.jit.script` is deprecated. Please switch to `torch.compile` or `torch.export`.
#   warnings.warn(
# /home/girish/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor

predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-09-14 20:19:38,313 94986 sam3_video_predictor.py: 120: using the following GPU IDs: [0]
# INFO 2026-09-14 20:19:38,394 94986 sam3_video_predictor.py: 136:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-09-14 20:19:38,395 94986 sam3_video_predictor.py: 138: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-09-14 20:19:43,056 94986 sam3_video_base.py: 354: setting max_num_objects=10000 and num_obj_for_compile=16
# [W914 20:19:47.290999189 CUDACachingAllocator.cpp:3934] memory allocation failed with OOM on device 0 while trying to allocate 20971520 bytes (free: 11862016, total: 6051135488).
# [W914 20:19:47.291155781 CUDACachingAllocator.cpp:3934] memory allocation failed with OOM on device 0 while trying to allocate 20971520 bytes (free: 11862016, total: 6051135488).
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sam3.model_builder import build_sam3_video_predictor
#       2
# ----> 3 predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model_builder.py:818, in build_sam3_video_predictor(gpus_to_use, *model_args, **model_kwargs)
#     817 def build_sam3_video_predictor(*model_args, gpus_to_use=None, **model_kwargs):
# --> 818     return Sam3VideoPredictorMultiGPU(
#     819         *model_args, gpus_to_use=gpus_to_use, **model_kwargs
#     820     )
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_predictor.py:139, in Sam3VideoPredictorMultiGPU.__init__(self, gpus_to_use, *model_args, **model_kwargs)
#     136     logger.info("\n\n\n\t*** START loading model on all ranks ***\n\n")
#     138 logger.info(f"loading model on {self.rank_str} -- this could take a while ...")
# --> 139 super().__init__(*model_args, **model_kwargs)
#     140 logger.info(f"loading model on {self.rank_str} -- DONE locally")
#     142 if self.world_size > 1 and self.rank == 0:
#     143     # start the worker processes *after* the model is loaded in the main process
#     144     # so that the main process can run torch.compile and fill the cache first
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_predictor.py:44, in Sam3VideoPredictor.__init__(self, checkpoint_path, bpe_path, has_presence_token, geo_encoder_use_img_cross_attn, strict_state_dict_loading, async_loading_frames, video_loader_type, apply_temporal_disambiguation, compile)
#      40 self.video_loader_type = video_loader_type
#      41 from sam3.model_builder import build_sam3_video_model
#      43 self.model = (
# ---> 44     build_sam3_video_model(
#      45         checkpoint_path=checkpoint_path,
#      46         bpe_path=bpe_path,
#      47         has_presence_token=has_presence_token,
#      48         geo_encoder_use_img_cross_attn=geo_encoder_use_img_cross_attn,
#      49         strict_state_dict_loading=strict_state_dict_loading,
#      50         apply_temporal_disambiguation=apply_temporal_disambiguation,
#      51         compile=compile,
#      52     )
#      53     .cuda()
#      54     .eval()
#      55 )
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model_builder.py:813, in build_sam3_video_model(checkpoint_path, load_from_HF, bpe_path, has_presence_token, geo_encoder_use_img_cross_attn, strict_state_dict_loading, apply_temporal_disambiguation, device, compile)
#     810     if unexpected_keys:
#     811         print(f"Unexpected keys: {unexpected_keys}")
# --> 813 model.to(device=device)
#     814 return model
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1388, in Module.to(self, *args, **kwargs)
#    1385         else:
#    1386             raise
# -> 1388 return self._apply(convert)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 # _apply is traced by dynamo at the bytecode level, and torch._subclasses
#     936 # is in dynamo's MOD_SKIPLIST, revisit later for c++
#     937 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 # _apply is traced by dynamo at the bytecode level, and torch._subclasses
#     936 # is in dynamo's MOD_SKIPLIST, revisit later for c++
#     937 from torch._subclasses.fake_tensor import FakeTensor
#
#     [... skipping similar frames: Module._apply at line 933 (5 times)]
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 # _apply is traced by dynamo at the bytecode level, and torch._subclasses
#     936 # is in dynamo's MOD_SKIPLIST, revisit later for c++
#     937 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:966, in Module._apply(self, fn, recurse)
#     962 # Tensors stored in modules are graph leaves, and we don't want to
#     963 # track autograd history of `param_applied`, so we have to use
#     964 # `with torch.no_grad():`
#     965 with torch.no_grad():
# --> 966     param_applied = fn(param)
#     967 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     969 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1374, in Module.to.<locals>.convert(t)
#    1367     if convert_to_format is not None and t.dim() in (4, 5):
#    1368         return t.to(
#    1369             device,
#    1370             dtype if t.is_floating_point() or t.is_complex() else None,
#    1371             non_blocking,
#    1372             memory_format=convert_to_format,
#    1373         )
# -> 1374     return t.to(
#    1375         device,
#    1376         dtype if t.is_floating_point() or t.is_complex() else None,
#    1377         non_blocking,
#    1378     )
#    1379 except NotImplementedError as e:
#    1380     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 11.31 MiB is free. Process 93608 has 4.45 GiB memory in use. Including non-PyTorch memory, this process has 1.15 GiB memory in use. Of the allocated memory 1011.40 MiB is allocated by PyTorch, and 68.60 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/0001"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (image folder) [rank=0]: 100%|██████████| 270/270 [00:04<00:00, 54.10it/s]
# INFO 2026-09-13 13:52:28,031 66339 sam3_base_predictor.py: 146: started new session b94e65b7-81a0-413d-a4f4-e47818f2cbdd

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
import torch

print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 1            |        cudaMalloc retries: 2         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   5445 MiB |   5487 MiB |  21117 MiB |  15672 MiB |
# |       from large pool |   5366 MiB |   5407 MiB |  20764 MiB |  15398 MiB |
# |       from small pool |     79 MiB |     83 MiB |    353 MiB |    273 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         |   5445 MiB |   5487 MiB |  21117 MiB |  15672 MiB |
# |       from large pool |   5366 MiB |   5407 MiB |  20764 MiB |  15398 MiB |
# |       from small pool |     79 MiB |     83 MiB |    353 MiB |    273 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |   5436 MiB |   5476 MiB |  21087 MiB |  15651 MiB |
# |       from large pool |   5356 MiB |   5397 MiB |  20734 MiB |  15378 MiB |
# |       from small pool |     79 MiB |     83 MiB |    352 MiB |    273 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |   5612 MiB |   5614 MiB |   5826 MiB | 219136 KiB |
# |       from large pool |   5530 MiB |   5530 MiB |   5740 MiB | 215040 KiB |
# |       from small pool |     82 MiB |     84 MiB |     86 MiB |   4096 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory | 147707 KiB | 208288 KiB |   9758 MiB |   9614 MiB |
# |       from large pool | 145392 KiB | 206864 KiB |   9339 MiB |   9197 MiB |
# |       from small pool |   2315 KiB |   4344 KiB |    418 MiB |    416 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |    2341    |    2372    |    6759    |    4418    |
# |       from large pool |     338    |     342    |    1598    |    1260    |
# |       from small pool |    2003    |    2036    |    5161    |    3158    |
# |---------------------------------------------------------------------------|
# | Active allocs         |    2341    |    2372    |    6759    |    4418    |
# |       from large pool |     338    |     342    |    1598    |    1260    |
# |       from small pool |    2003    |    2036    |    5161    |    3158    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |     232    |     235    |     242    |      10    |
# |       from large pool |     191    |     194    |     199    |       8    |
# |       from small pool |      41    |      42    |      43    |       2    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      80    |      90    |    2251    |    2171    |
# |       from large pool |      72    |      73    |    1031    |     959    |
# |       from small pool |       8    |      17    |    1220    |    1212    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)
# Out:
# [W913 13:52:28.908850708 CUDACachingAllocator.cpp:3934] memory allocation failed with OOM on device 0 while trying to allocate 85983232 bytes (free: 86441984, total: 6051135488).
# [W913 13:52:29.536708316 CUDACachingAllocator.cpp:3934] memory allocation failed with OOM on device 0 while trying to allocate 23068672 bytes (free: 21430272, total: 6051135488).
# [W913 13:52:29.540120736 CUDACachingAllocator.cpp:3934] memory allocation failed with OOM on device 0 while trying to allocate 23068672 bytes (free: 23527424, total: 6051135488).
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[12], line 3
#       1 prompt_text_str = "person"
#       2 frame_idx = 0  # add a text prompt on frame 0
# ----> 3 response = predictor.handle_request(
#       4     request=dict(
#       5         type="add_prompt",
#       6         session_id=session_id,
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_predictor.py:170, in Sam3VideoPredictorMultiGPU.handle_request(self, request)
#     167     for rank in range(1, self.world_size):
#     168         self.command_queues[rank].put((request, False))
# --> 170 response = super().handle_request(request)
#     172 if self.world_size > 1:
#     173     torch.distributed.barrier()  # wait for all ranks to finish
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_base_predictor.py:61, in Sam3BasePredictor.handle_request(self, request)
#      54     return self.start_session(
#      55         resource_path=request["resource_path"],
#      56         session_id=request.get("session_id", None),
#      57         offload_video_to_cpu=request.get("offload_video_to_cpu", False),
#      58         offload_state_to_cpu=request.get("offload_state_to_cpu", False),
#      59     )
#      60 elif request_type == "add_prompt":
# ---> 61     return self.add_prompt(
#      62         session_id=request["session_id"],
#      63         frame_idx=request["frame_index"],
#      64         text=request.get("text", None),
#      65         points=request.get("points", None),
#      66         point_labels=request.get("point_labels", None),
#      67         clear_old_points=request.get("clear_old_points", True),
#      68         bounding_boxes=request.get("bounding_boxes", None),
#      69         bounding_box_labels=request.get("bounding_box_labels", None),
#      70         clear_old_boxes=request.get("clear_old_boxes", True),
#      71         output_prob_thresh=request.get(
#      72             "output_prob_thresh",
#      73             getattr(self, "default_output_prob_thresh", 0.5),
#      74         ),
#      75         obj_id=request.get("obj_id", None),
#      76         rel_coordinates=request.get("rel_coordinates", True),
#      77     )
#      78 elif request_type == "remove_object":
#      79     return self.remove_object(
#      80         session_id=request["session_id"],
#      81         frame_idx=request.get("frame_index", 0),
#      82         obj_id=request["obj_id"],
#      83     )
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_base_predictor.py:206, in Sam3BasePredictor.add_prompt(self, session_id, frame_idx, text, points, point_labels, clear_old_points, bounding_boxes, bounding_box_labels, clear_old_boxes, output_prob_thresh, obj_id, rel_coordinates)
#     203 filtered_kwargs = {k: v for k, v in kwargs.items() if k in valid_params}
#     205 with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
# --> 206     frame_idx, outputs = self.model.add_prompt(**filtered_kwargs)
#     207 return {"frame_index": frame_idx, "outputs": outputs}
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_inference.py:1395, in Sam3VideoInferenceWithInstanceInteractivity.add_prompt(self, inference_state, frame_idx, text_str, boxes_xywh, box_labels, points, point_labels, obj_id, rel_coordinates)
#    1384     return self.add_tracker_new_points(
#    1385         inference_state,
#    1386         frame_idx,
#    (...)   1391         use_prev_mem_frame=self.use_prev_mem_frame,
#    1392     )
#    1393 else:
#    1394     # SAM3 prompts
# -> 1395     return super().add_prompt(
#    1396         inference_state,
#    1397         frame_idx,
#    1398         text_str=text_str,
#    1399         boxes_xywh=boxes_xywh,
#    1400         box_labels=box_labels,
#    1401     )
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_inference.py:903, in Sam3VideoInference.add_prompt(self, inference_state, frame_idx, text_str, boxes_xywh, box_labels)
#     897     boxes_cxcywh, box_labels, geometric_prompt = self._get_visual_prompt(
#     898         inference_state, frame_idx, boxes_cxcywh, box_labels
#     899     )
#     901     inference_state["per_frame_geometric_prompt"][frame_idx] = geometric_prompt
# --> 903 out = self._run_single_frame_inference(
#     904     inference_state, frame_idx, reverse=False
#     905 )
#     906 return frame_idx, self._postprocess_output(inference_state, out)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_inference.py:380, in Sam3VideoInference._run_single_frame_inference(self, inference_state, frame_idx, reverse)
#     369 has_geometric_prompt = (
#     370     inference_state["per_frame_geometric_prompt"][frame_idx] is not None
#     371 )
#     372 # run inference for the current frame
#     373 (
#     374     obj_id_to_mask,
#     375     obj_id_to_score,
#     376     tracker_states_local_new,
#     377     tracker_metadata_new,
#     378     frame_stats,
#     379     _,
# --> 380 ) = self._det_track_one_frame(
#     381     frame_idx=frame_idx,
#     382     num_frames=inference_state["num_frames"],
#     383     reverse=reverse,
#     384     input_batch=input_batch,
#     385     geometric_prompt=(
#     386         inference_state["constants"]["empty_geometric_prompt"]
#     387         if not has_geometric_prompt
#     388         else inference_state["per_frame_geometric_prompt"][frame_idx]
#     389     ),
#     390     tracker_states_local=tracker_states_local,
#     391     tracker_metadata_prev=inference_state["tracker_metadata"],
#     392     feature_cache=inference_state["feature_cache"],
#     393     orig_vid_height=inference_state["orig_height"],
#     394     orig_vid_width=inference_state["orig_width"],
#     395     is_image_only=inference_state["is_image_only"],
#     396     allow_new_detections=has_text_prompt or has_geometric_prompt,
#     397 )
#     398 # update inference state
#     399 inference_state["tracker_inference_states"] = tracker_states_local_new
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_base.py:413, in Sam3VideoBase._det_track_one_frame(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only, allow_new_detections)
#     396 """
#     397 This function handles one-step inference for the DenseTracking model in an SPMD manner.
#     398 At a high-level, all GPUs execute the same function calls as if it's done on a single GPU,
#    (...)    405   it contains both global and local masklet information
#     406 """
#     408 # Step 1: run backbone and detector in a distributed manner -- this is done via Sam3ImageOnVideoMultiGPU,
#     409 # a MultiGPU model (assigned to `self.detector`) that shards frames in a round-robin manner.
#     410 # It returns a "det_out" dict for `frame_idx` and fills SAM2 backbone features for `frame_idx`
#     411 # into `feature_cache`. Despite its distributed inference under the hood, the results would be
#     412 # the same as if it is running backbone and detector for every frame on a single GPU.
# --> 413 det_out = self.run_backbone_and_detection(
#     414     frame_idx=frame_idx,
#     415     num_frames=num_frames,
#     416     reverse=reverse,
#     417     input_batch=input_batch,
#     418     geometric_prompt=geometric_prompt,
#     419     feature_cache=feature_cache,
#     420     allow_new_detections=allow_new_detections,
#     421 )
#     423 # Step 2: each GPU propagates its local SAM2 states to get the SAM2 prediction masks.
#     424 # the returned `tracker_low_res_masks_global` contains the concatenated masklet predictions
#     425 # gathered from all GPUs (as if they are propagated on a single GPU). Note that this step only
#     426 # runs the SAM2 propagation step, but doesn't encode new memory for the predicted masks;
#     427 # we defer memory encoding to `run_tracker_update_execution_phase` after resolving all heuristics.
#     428 if tracker_metadata_prev == {}:
#     429     # initialize masklet metadata if it's uninitialized (empty dict)
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_video_base.py:581, in Sam3VideoBase.run_backbone_and_detection(self, frame_idx, num_frames, input_batch, geometric_prompt, feature_cache, reverse, allow_new_detections)
#     578 start_frame_idx = tracking_bounds.get("propagate_in_video_start_frame_idx")
#     580 # pyre-fixme[29]: `Union[Module, Tensor]` is not a function.
# --> 581 sam3_image_out, _ = self.detector.forward_video_grounding_multigpu(
#     582     backbone_out={
#     583         "img_batch_all_stages": input_batch.img_batch,
#     584         **text_outputs,
#     585     },
#     586     find_inputs=input_batch.find_inputs,
#     587     geometric_prompt=geometric_prompt,
#     588     frame_idx=frame_idx,
#     589     num_frames=num_frames,
#     590     multigpu_buffer=feature_cache["multigpu_buffer"],
#     591     track_in_reverse=reverse,
#     592     # also get the SAM2 backbone features
#     593     return_tracker_backbone_feats=True,
#     594     # run NMS as a part of distributed computation
#     595     run_nms=self.det_nms_thresh > 0.0,
#     596     nms_prob_thresh=self.score_threshold_detection,
#     597     nms_iou_thresh=self.det_nms_thresh,
#     598     # pass max_frame_num_to_track to respect tracking limits
#     599     max_frame_num_to_track=max_frame_num_to_track,
#     600     propagate_in_video_start_frame_idx=start_frame_idx,
#     601 )
#     602 # note: detections in `sam3_image_out` has already gone through NMS
#     603 pred_probs = sam3_image_out["pred_logits"].squeeze(-1).sigmoid()
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_image.py:759, in Sam3ImageOnVideoMultiGPU.forward_video_grounding_multigpu(self, backbone_out, find_inputs, geometric_prompt, frame_idx, num_frames, multigpu_buffer, track_in_reverse, return_sam2_backbone_feats, run_nms, nms_prob_thresh, nms_iou_thresh, **kwargs)
#     757 if frame_idx not in multigpu_buffer:
#     758     with torch.profiler.record_function("build_multigpu_buffer_next_chunk1"):
# --> 759         self._build_multigpu_buffer_next_chunk(
#     760             backbone_out=backbone_out,
#     761             find_inputs=find_inputs,
#     762             geometric_prompt=geometric_prompt,
#     763             frame_idx_begin=frame_idx_curr_b,
#     764             frame_idx_end=frame_idx_curr_e,
#     765             num_frames=num_frames,
#     766             multigpu_buffer=multigpu_buffer,
#     767             run_nms=run_nms,
#     768             nms_prob_thresh=nms_prob_thresh,
#     769             nms_iou_thresh=nms_iou_thresh,
#     770         )
#     772 # read out the current frame's results from `multigpu_buffer`
#     773 out = {}
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_image.py:840, in Sam3ImageOnVideoMultiGPU._build_multigpu_buffer_next_chunk(self, backbone_out, find_inputs, geometric_prompt, frame_idx_begin, frame_idx_end, num_frames, multigpu_buffer, run_nms, nms_prob_thresh, nms_iou_thresh)
#     838 # `forward_grounding` (from base class `Sam3ImageOnVideo`) runs the detector on a single frame
#     839 with torch.profiler.record_function("forward_grounding"):
# --> 840     out_local = self.forward_grounding(
#     841         backbone_out=backbone_out,
#     842         find_input=find_inputs[frame_idx_local_gpu],
#     843         find_target=None,
#     844         geometric_prompt=geometric_prompt,
#     845     )
#     846 if run_nms:
#     847     with torch.profiler.record_function("nms_masks"):
#     848         # run NMS as a post-processing step on top of the detection outputs
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_image.py:484, in Sam3Image.forward_grounding(self, backbone_out, find_input, find_target, geometric_prompt, **kwargs)
#     482     if "id_mapping" in backbone_out and backbone_out["id_mapping"] is not None:
#     483         seg_img_ids = backbone_out["id_mapping"][seg_img_ids]
# --> 484     self._run_segmentation_heads(
#     485         out=out,
#     486         backbone_out=backbone_out,
#     487         img_ids=seg_img_ids,
#     488         vis_feat_sizes=encoder_out["vis_feat_sizes"],
#     489         encoder_hidden_states=out["encoder_hidden_states"],
#     490         prompt=prompt,
#     491         prompt_mask=prompt_mask,
#     492         hs=hs,
#     493     )
#     495 if self.training or self.num_interactive_steps_val > 0:
#     496     self._compute_matching(out, self.back_convert(find_target))
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/sam3_image.py:403, in Sam3Image._run_segmentation_heads(self, out, backbone_out, img_ids, vis_feat_sizes, encoder_hidden_states, prompt, prompt_mask, hs)
#     401 num_o2m = hs.size(2) - num_o2o
#     402 obj_queries = hs if self.o2m_mask_predict else hs[:, :, :num_o2o]
# --> 403 seg_head_outputs = activation_ckpt_wrapper(self.segmentation_head)(
#     404     backbone_feats=backbone_out["backbone_fpn"],
#     405     obj_queries=obj_queries,
#     406     image_ids=img_ids,
#     407     encoder_hidden_states=encoder_hidden_states,
#     408     act_ckpt_enable=self.training and self.use_act_checkpoint_seg_head,
#     409     prompt=prompt,
#     410     prompt_mask=prompt_mask,
#     411 )
#     412 aux_masks = False  # self.aux_loss and self.segmentation_head.aux_masks
#     413 for k, v in seg_head_outputs.items():
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/act_ckpt_utils.py:88, in activation_ckpt_wrapper.<locals>.act_ckpt_wrapper(act_ckpt_enable, use_reentrant, *args, **kwargs)
#      84     ret = checkpoint.checkpoint(
#      85         module, *args, use_reentrant=use_reentrant, **kwargs
#      86     )
#      87 else:
# ---> 88     ret = module(*args, **kwargs)
#      90 return ret
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/maskformer_segmentation.py:321, in UniversalSegmentationHead.forward(self, backbone_feats, obj_queries, image_ids, encoder_hidden_states, prompt, prompt_mask, **kwargs)
#     310     pooled_enc = encoder_hidden_states.mean(0)
#     311     presence_logit = (
#     312         self.presence_head(
#     313             pooled_enc.view(1, bs, 1, self.d_model),
#    (...)    318         .squeeze(1)
#     319     )
# --> 321 pixel_embed = self._embed_pixels(
#     322     backbone_feats=backbone_feats,
#     323     image_ids=image_ids,
#     324     encoder_hidden_states=encoder_hidden_states,
#     325 )
#     327 instance_embeds = self.instance_seg_head(pixel_embed)
#     329 if self.no_dec:
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/maskformer_segmentation.py:143, in SegmentationHead._embed_pixels(self, backbone_feats, image_ids, encoder_hidden_states)
#     141 backbone_visual_feats[-1] = encoder_visual_embed
#     142 if self.act_ckpt:
# --> 143     pixel_embed = checkpoint.checkpoint(
#     144         self.pixel_decoder, backbone_visual_feats, use_reentrant=False
#     145     )
#     146 else:
#     147     pixel_embed = self.pixel_decoder(backbone_visual_feats)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/_compile.py:54, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#      52     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 54 return disable_fn(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1548, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#    1540             with fx_traceback.annotate(
#    1541                 {
#    1542                     "_torchdynamo_disable": True,
#    (...)   1545                 }
#    1546             ):
#    1547                 return fn(*args, **kwargs)
# -> 1548     return fn(*args, **kwargs)
#    1549 finally:
#    1550     if callback is not None:
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/checkpoint.py:606, in checkpoint(function, use_reentrant, preserve_rng_state, context_fn, determinism_check, debug, early_stop, respect_saved_tensors_hooks, *args, **kwargs)
#     592         raise ValueError(
#     593             "Unexpected keyword arguments: " + ",".join(arg for arg in kwargs)
#     594         )
#     595     return functools.partial(
#     596         _make_checkpoint_wrapper,
#     597         use_reentrant=use_reentrant,
#    (...)    603         respect_saved_tensors_hooks=respect_saved_tensors_hooks,
#     604     )
# --> 606 return _checkpoint_impl(
#     607     function,
#     608     args,
#     609     kwargs,
#     610     use_reentrant=use_reentrant,
#     611     preserve_rng_state=preserve_rng_state,
#     612     context_fn=context_fn,
#     613     determinism_check=determinism_check,
#     614     debug=debug,
#     615     early_stop=early_stop,
#     616     respect_saved_tensors_hooks=respect_saved_tensors_hooks,
#     617 )
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/checkpoint.py:681, in _checkpoint_impl(function, args, kwargs, use_reentrant, preserve_rng_state, context_fn, determinism_check, debug, early_stop, respect_saved_tensors_hooks)
#     679 except BaseException as e:
#     680     try:
# --> 681         gen.throw(e)
#     682     except StopIteration as stop:
#     683         raise RuntimeError(
#     684             "torch.utils.checkpoint: the forward context provided by "
#     685             "context_fn suppressed an exception raised during the "
#     686             "checkpointed forward. This is not supported because "
#     687             "checkpoint cannot return a value for a failed forward."
#     688         ) from stop
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/checkpoint.py:1972, in _checkpoint_without_reentrant_generator_impl(fn, args, kwargs, preserve_rng_state, context_fn, determinism_check, debug, early_stop, respect_saved_tensors_hooks)
#    1964 new_frame = _CheckpointFrame(
#    1965     recompute_fn,
#    1966     _enable_checkpoint_early_stop if _enable_checkpoint_early_stop is not None else early_stop,
#    1967     unpack_error_cb,
#    1968     metadata_fn
#    1969 )
#    1971 if not torch.is_grad_enabled():
# -> 1972     yield
#    1973     return
#    1975 if (
#    1976     isinstance(forward_context, _CachingTorchDispatchMode)
#    1977     and torch._C._autograd._top_saved_tensors_default_hooks(False) is not None
#    1978 ):
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/utils/checkpoint.py:678, in _checkpoint_impl(function, args, kwargs, use_reentrant, preserve_rng_state, context_fn, determinism_check, debug, early_stop, respect_saved_tensors_hooks)
#     676 next(gen)
#     677 try:
# --> 678     ret = function(*args, **kwargs)
#     679 except BaseException as e:
#     680     try:
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~/Documents/Projects/SAM3/sam3/sam3/model/maskformer_segmentation.py:231, in PixelDecoder.forward(self, backbone_feats)
#     229         layer_idx = 0
#     230     prev_fpn = self.conv_layers[layer_idx](prev_fpn)
# --> 231     prev_fpn = F.relu(self.norms[layer_idx](prev_fpn))
#     233 return prev_fpn
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/modules/normalization.py:334, in GroupNorm.forward(self, input)
#     333 def forward(self, input: Tensor) -> Tensor:
# --> 334     return F.group_norm(input, self.num_groups, self.weight, self.bias, self.eps)
#
# File ~/Documents/Projects/SAM3/.venv/lib/python3.12/site-packages/torch/nn/functional.py:3048, in group_norm(input, num_groups, weight, bias, eps)
#    3041     raise RuntimeError(
#    3042         f"Expected at least 2 dimensions for input tensor but received {input.dim()}"
#    3043     )
#    3044 _verify_batch_size(
#    3045     [input.size(0) * input.size(1) // num_groups, num_groups]
#    3046     + list(input.size()[2:])
#    3047 )
# -> 3048 return torch.group_norm(
#    3049     input, num_groups, weight, bias, eps, torch.backends.cudnn.enabled
#    3050 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 22.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 22.44 MiB is free. Including non-PyTorch memory, this process has 5.59 GiB memory in use. Of the allocated memory 5.36 GiB is allocated by PyTorch, and 124.74 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
